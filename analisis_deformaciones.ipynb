# %%
import ipywidgets as widgets
from IPython.display import display

# %%
class PerfilesExplorador:
    def __init__(self, data):
        self.data = data
        self.tipos = data['Tipo'].unique()

        self.tipo_dropdown = widgets.Dropdown(
            options=self.tipos,
            description='Tipo:'
        )

        self.designacion_output = widgets.Output()

        self.tipo_dropdown.observe(self.on_tipo_change, names='value')

        display(self.tipo_dropdown, self.designacion_output)

    def on_tipo_change(self, change):
        selected_tipo = change.new
        with self.designacion_output:
            self.designacion_output.clear_output()
            designaciones = self.data[self.data['Tipo'] == selected_tipo]['Designacion'].unique()
            if len(designaciones) > 0:
                print(f"Perfiles disponibles para familia: {selected_tipo}:")
                for designacion in designaciones:
                    print(designacion)
            else:
                print(f"No hay perfiles disponibles para familia: {selected_tipo}.")


# Create an instance of SteelProfileExplorer with your data
explorer = PerfilesExplorador(df)
# Out:
# Dropdown(description='Tipo:', options=('IPN', 'IPB', 'IPBl', 'IPBv', 'IPE', 'W', 'HP', 'M'), value='IPN')
# Output()

# %%
perfiles_dict = {'IPN':['200','300','400'],'IPB':['300','400'],'W':['8x10','8x18']}

# %%
# %run ./clase_perfil.ipynb

# %% [markdown]
# ## Análisis de deflexiones para casos comunes

# %% [markdown]
# | Loading Condition              | Deflection (δ)                   |
# |--------------------------------|----------------------------------|
# | Simplemente apoyado, Carga centrada P   | δ = (P * L^3) / (48 * E * I) |
# | Simplemente apoyado, Carga uniforme q  | δ = (5 * q * L^4) / (384 * E * I) |
# | Cantilever, Carga extrema P            | δ = (P * L^3) / (3 * E * I)      |
# | Cantilever, Carga uniforme q        | δ = (q * L^4) / (8 * E * I)      |
# | Empotrado-Empotrado, Carga centrada P        | δ = (P * L^3) / (192 * E * I)    |
# | Empotrado-Empotrado, Carga uniforme q       | δ = (q * L^4) / (384 * E * I)    |

# %% [markdown]
# ### Selección de carga

# %%
from ipywidgets import interact, widgets

# Function that takes a parameter
def process_selected_value(selected_value):
    global caso
    caso = selected_value  # Save the selected value in a global variable

# Create a dropdown widget
dropdown = widgets.Dropdown(
    options=['Simplemente apoyado, carga centrada', 'Simplemente apoyado, carga uniforme', 'Voladizo, carga extremo','Voladizo, carga uniforme', 'Empotrado-Empotrado, carga centrada','Empotrado-Empotrado, carga uniforme'],
    description='Tipo de carga'
)

# Use interact to bind the dropdown to the function
interact(process_selected_value, selected_value=dropdown)
# Out:
# interactive(children=(Dropdown(description='Tipo de carga', options=('Simplemente apoyado, carga centrada', 'S…
# <function __main__.process_selected_value(selected_value)>

# %%
selector_carga
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\agust\Documents\cirsoc301\cirsoc301\analisis_deformaciones.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/agust/Documents/cirsoc301/cirsoc301/analisis_deformaciones.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> selector_carga
#
# NameError: name 'selector_carga' is not defined

# %% [markdown]
# ### Definicion de perfiles

# %%
familia_perfiles.deformacion_comparativa(perfiles_dict,caso,2,400,240,'fuerte')
# Out:
#             Deflexión para LC y perfil dado: 0.62 mm
#             Deflexión admisible: 16.67 mm
#             Ratio para tolerancia dada: 3.74 %
#
#             Deflexión para LC y perfil dado: 0.14 mm
#             Deflexión admisible: 16.67 mm
#             Ratio para tolerancia dada: 0.82 %
#
#             Deflexión para LC y perfil dado: 0.05 mm
#             Deflexión admisible: 16.67 mm
#             Ratio para tolerancia dada: 0.27 %
#
#             Deflexión para LC y perfil dado: 0.05 mm
#             Deflexión admisible: 16.67 mm
#             Ratio para tolerancia dada: 0.32 %
#
#             Deflexión para LC y perfil dado: 0.02 mm
#             Deflexión admisible: 16.67 mm
#             Ratio para tolerancia dada: 0.14 %
#
#             Deflexión para LC y perfil dado: 1.04 mm
#             Deflexión admisible: 16.67 mm
#             Ratio para tolerancia dada: 6.24 %
#
#             Deflexión para LC y perfil dado: 0.52 mm
#             Deflexión admisible: 16.67 mm
#             Ratio para tolerancia dada: 3.11 %

# %%
perfil.deformacion_tipica(caso,25,400,100,'debil')
# Out:
#             Deflexión para LC y perfil dado: 0.49 mm
#             Deflexión admisible: 40.00 mm
#             Ratio para tolerancia dada: 1.22 %
# (None, 0.48676012461059187)

# %%
perfil.deformacion_comparativa(perfiles_dict,caso,25,400,100,'debil')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\adiez\Documents\cirsoc301\cirsoc301\analisis_deformaciones.ipynb Celda 16 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adiez/Documents/cirsoc301/cirsoc301/analisis_deformaciones.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> perfil.deformacion_comparativa(perfiles_dict,caso,25,400,100,'debil')
#
# File ~\AppData\Local\Temp\ipykernel_9020\3738116442.py:121, in dobleT.deformacion_comparativa(self, lista_perfiles, caso, carga, largo, tolerancia, eje)
#     118 def_admisible = (largo*10/tolerancia)
#     119 for familia, designacion in lista_perfiles.items():
#     120     # Create instances of your class based on familia and designacion
# --> 121     instance = dobleT(self.data, familia, designacion)
#     123     # Calculate deflection for the instance
#     124     deflection = instance.deformacion_tipica(caso, carga, largo, tolerancia, eje)[1]
#
# File ~\AppData\Local\Temp\ipykernel_9020\3738116442.py:6, in dobleT.__init__(self, data, familia, designacion)
#       4 def __init__(self, data, familia, designacion):
#       5     self.data = data
# ----> 6     self.data = self.data[(self.data['Tipo'] == familia) & (self.data['Designacion'] == designacion)]
#       7     self.name = self.data.iloc[0]['Tipo'] + self.data.iloc[0]['Designacion']
#       8     self.d = self.data.iloc[0]['d']
#
# File c:\Users\adiez\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File c:\Users\adiez\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:42, in OpsMixin.__eq__(self, other)
#      40 @unpack_zerodim_and_defer("__eq__")
#      41 def __eq__(self, other):
# ---> 42     return self._cmp_method(other, operator.eq)
#
# File c:\Users\adiez\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6245 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\adiez\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:264, in comparison_op(left, right, op)
#     259 if isinstance(rvalues, (np.ndarray, ABCExtensionArray)):
#     260     # TODO: make this treatment consistent across ops and classes.
#     261     #  We are not catching all listlikes here (e.g. frozenset, tuple)
#     262     #  The ambiguous case is object-dtype.  See GH#27803
#     263     if len(lvalues) != len(rvalues):
# --> 264         raise ValueError(
#     265             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     266         )
#     268 if should_extension_dispatch(lvalues, rvalues) or (
#     269     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     270     and not is_object_dtype(lvalues.dtype)
#     271 ):
#     272     # Call the method on lvalues
#     273     res_values = op(lvalues, rvalues)
#
# ValueError: ('Lengths must match to compare', (1,), (2,))

# %%
perfiles_dict.items()
# Out:
# dict_items([('IPN', '300'), ('IPB', '300')])

# %%
perfilaas = dobleT(df,'IPN','400')

# %%
# Out:
# d: 400.0 mm
# bf: 155.0 mm
# tf: 21.6 mm
# hw: 323.0 mm
# tw=r1: 14.4 mm
# r2: 8.6 mm
# bf/2tf: 3.6
# hw/tw: 22.4
# Ag: 118.0 cm2
# Peso: 92.4 kg/m
# Ix: 29210.0 cm4
# Sx: 1460.0 cm3
# rx: 15.7 cm
# Qx: 857.0 cm3
# Zx: 1714.0 cm3
# Iy: 1160.0 cm4
# Sy: 149.0 cm3
# ry: 3.1 cm
# Qy: 125.5 cm3
# 1.5Sy: 223.5 cm3
# Zy: 251.0 cm3
# w1: 86.0 mm
# d1: 23.0 mm
# w4: 34.5 mm
# t1: 16.2 mm
# w3: nan mm
# J: 140.0 cm4
# Cw: 419600.0 cm6
# X1: 24270.0 MPa
# X2: 2.7000000000000002e-05 MPA^-2 * 10^5
